# %% [markdown]
# <a href="https://colab.research.google.com/github/devchh/MRI-Pi/blob/main/See_Sliced_Image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install dipy

# %%
import nibabel
import scipy
import matplotlib.pyplot as plt
import numpy as np
import dipy
nibabel.load("/content/drive/MyDrive/Colab Notebooks/100307/T1w/Diffusion/misc/split/vol0075.nii.gz")
image = nibabel.load("/content/drive/MyDrive/Colab Notebooks/100307/T1w/Diffusion/misc/split/vol0075.nii.gz").get_fdata()
image.shape
test = image[:,:,0,0]
plt.imshow(image[:,:,0,0])
plt.show()
